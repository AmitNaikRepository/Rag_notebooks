# %% [markdown]
# # ☁️ AWS Basics
#
# **Deploy LLM apps to AWS**
#
# ## Overview
# **What you'll learn:** AWS fundamentals, IAM, regions, services overview
#
# **Time:** 45 min | **Difficulty:** 🟡

# %% [markdown]
# ## ☁️ AWS Services for LLM Apps
#
# **Compute:** EC2, Lambda, ECS, EKS
# **Storage:** S3, EBS, EFS
# **Database:** RDS, DynamoDB
# **ML:** SageMaker, Bedrock
# **Networking:** VPC, ALB, CloudFront

# %% [markdown]
# ## ✅ Summary
# AWS provides complete infrastructure for LLM applications.
# ### Next: `15_cloud_aws/02_ec2.ipynb`
